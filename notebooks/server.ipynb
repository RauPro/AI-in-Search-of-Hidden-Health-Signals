# %%
import requests

# The URL of your local server (port 8000 is default for Uvicorn)
url = "https://healthcare.fastwaydata.com//predict"

# The data payload (matching your Pydantic model)
# payload = {
#     "age": 50.0,
#     "female": 1,
#     "ethnicity": "Black",
#     "height": 1.62,
#     "weight": 98.5,
#     "bmi": 37.5,
#     "self_rated_health": 5.0,
#     "mobility": 4.0,
#     "gross_motor": 3.0,
#     "fine_motor": 1.0,
#     "large_muscle": 3.0,
#     "adl": 2.0,
#     "iadl": 3.0,
#     "cognition": 1,
#     "memory_recall": 3.0,
#     "serial7": 1.0,
#     "immediate_recall": 4,
#     "delayed_recall": 2,
#     "cesd": 6.0,
#     "depressed": 1,
#     "lonely": 1,
#     "restless_sleep": 1,
#     "effort": 1,
#     "ever_smoked": 1,
#     "current_smoker": 1,
#     "drinks_per_day": 15,
#     "drink_days_week": 0.0,
#     "vigorous_activity": 1,
#     "working": 0,
#     "education": 10,
#     "edu_cat": 2,
#     "degree": 0
# }
payload ={
    "age": 76.0,
    "female": 1,
    "ethnicity": "Black",
    "height": 1.62,
    "weight": 98.5,
    "bmi": 37.5,
    "bmi_lag1": 34.2,
    "self_rated_health": 4.0,
    "self_rated_health_lag1": 2.0,
    "mobility": 4.0,
    "gross_motor": 3.0,
    "fine_motor": 1.0,
    "large_muscle": 3.0,
    "adl": 2.0,
    "iadl": 3.0,
    "cognition": 12.0,
    "memory_recall": 3.0,
    "serial7": 1.0,
    "immediate_recall": 4,
    "delayed_recall": 2,
    "cesd": 6.0,
    "depressed": 1,
    "lonely": 1,
    "restless_sleep": 1,
    "effort": 1,
    "ever_smoked": 1,
    "current_smoker": 0,
    "drinks_per_day": 0.0,
    "drink_days_week": 0.0,
    "vigorous_activity": 1,
    "working": 0,
    "education": 10,
    "edu_cat": 2,
    "degree": 0
}
try:
    # Send POST request
    response = requests.post(url, json=payload)
    
    # Check if request was successful
    if response.status_code == 200:
        print("✅ Success!")
        print(response.json())
    else:
        print(f"❌ Error {response.status_code}: {response.text}")

except requests.exceptions.ConnectionError:
    print("❌ Could not connect. Is 'server.py' running?")
# Out:
# ✅ Success!
# {'status': 'success', 'health_score': 66.0, 'risks': {'diabetes': 17.28, 'cvd': 33.05, 'stroke': 21.67, 'lung': 27.26, 'cancer': 22.76, 'hibp': 28.66, 'arthritis': 33.99, 'memory': 29.79, 'psychiatric': 29.86}, 'message': 'Prediction successful. Remember this is a screening tool, not a diagnosis.'}
